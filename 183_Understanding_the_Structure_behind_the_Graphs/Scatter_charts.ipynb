# %%
from bokeh.plotting import figure, output_file, show
import pandas
import numpy

df=pandas.DataFrame(columns=["X", "Y"])
df["X"]=[1,2,3,4,5]
df["Y"]=[5,6,4,5,3]

p = figure(plot_width=600, plot_height=400, title="Earthquake", toolbar_location="below")

p.title.text_color = "red"
p.title.text_font = "times"
p.title.text_font_style = "italic"

p.xaxis.minor_tick_line_color="red"
p.yaxis.minor_tick_line_color="red"

p.circle(df["X"], df["Y"], size=[i*2 for i in[5,8,11,14,17]], color="red", alpha=0.5)

output_file("plot_cdn.html", mode="cdn")
show(p)

#open plot_cdn.html in npp and show java script file

# %%
from bokeh.plotting import figure, output_file, show
import pandas
import numpy

df=pandas.DataFrame(columns=["X", "Y"])
df["X"]=[1,2,3,4,5]
df["Y"]=[5,6,4,5,3]

p = figure(plot_width=600, plot_height=400, title="Earthquake", toolbar_location="below")

p.title.text_color = "red"
p.title.text_font = "times"
p.title.text_font_style = "italic"

p.xaxis.minor_tick_line_color="red"
p.yaxis.minor_tick_line_color="red"

p.circle(df["X"], df["Y"], size=[i*2 for i in[5,8,11,14,17]], color="red", alpha=0.5)

output_file("plot_absolute.html", mode="absolute")
show(p)

#open plot_absolute.html in npp and show java script file

# %%
from bokeh.plotting import figure, output_file, show
import pandas
import numpy

df=pandas.DataFrame(columns=["X", "Y"])
df["X"]=[1,2,3,4,5]
df["Y"]=[5,6,4,5,3]

p = figure(plot_width=600, plot_height=400, title="Earthquake", toolbar_location="below")

p.title.text_color = "red"
p.title.text_font = "times"
p.title.text_font_style = "italic"

p.xaxis.minor_tick_line_color="red"
p.yaxis.minor_tick_line_color="red"

p.circle(df["X"], df["Y"], size=[i*2 for i in[5,8,11,14,17]], color="red", alpha=0.5)

output_file("plot_inline.html", mode="inline")
show(p)

#open plot_inline.html in npp and show java script file

# %%
#remove Tools and Logo

from bokeh.plotting import figure, output_file, show
import pandas
import numpy

df=pandas.DataFrame(columns=["X", "Y"])
df["X"]=[1,2,3,4,5]
df["Y"]=[5,6,4,5,3]

p = figure(plot_width=600, plot_height=400, toolbar_location="below", tools="", logo=None)

p.title.text="Earthquake"
p.title.text_color = "blue"
p.title.text_font = "times"
p.title.text_font_style = "italic"

p.xaxis.minor_tick_line_color="red"
p.yaxis.minor_tick_line_color="red"

p.circle(df["X"], df["Y"], size=[i*2 for i in[5,8,11,14,17]], color="blue", alpha=0.5)

output_file("plot.html")
show(p)

# %%
#remove Logo and Specific tools

from bokeh.plotting import figure, output_file, show
import pandas
import numpy

df=pandas.DataFrame(columns=["X", "Y"])
df["X"]=[1,2,3,4,5]
df["Y"]=[5,6,4,5,3]

p = figure(plot_width=600, plot_height=400, toolbar_location="below", tools="pan", logo=None)

p.title.text="Earthquake"
p.title.text_color = "blue"
p.title.text_font = "times"
p.title.text_font_style = "italic"

p.xaxis.minor_tick_line_color="red"
p.yaxis.minor_tick_line_color="red"

p.circle(df["X"], df["Y"], size=[i*2 for i in[5,8,11,14,17]], color="blue", alpha=0.5)

output_file("plot1.html")
show(p)
